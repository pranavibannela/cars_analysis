# %% [markdown]
# <a href="https://colab.research.google.com/github/pranavibannela/cars_analysis/blob/main/Cars_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import libraries

import math
import collections

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#importing dataset

cars = pd.read_csv('autoscout24-germany-dataset.csv')

# %% [markdown]
# <b>First look at the dataset:</b>

# %%
#check first and last 10 rows

cars.head(10)
# Out:
#    mileage        make    model               fuel       gear offerType  \
# 0   235000         BMW      316             Diesel     Manual      Used
# 1    92800  Volkswagen     Golf           Gasoline     Manual      Used
# 2   149300        SEAT     Exeo           Gasoline     Manual      Used
# 3    96200     Renault   Megane           Gasoline     Manual      Used
# 4   156000     Peugeot      308           Gasoline     Manual      Used
# 5   147000      Toyota    Auris  Electric/Gasoline  Automatic      Used
# 6    91894     Renault   Scenic             Diesel     Manual      Used
# 7   127500        Opel   Zafira           Gasoline     Manual      Used
# 8   115000       Mazda        3           Gasoline  Automatic      Used
# 9      104        Ford  Transit             Diesel     Manual      Used
#
#    price     hp  year
# 0   6800 116.00  2011
# 1   6877 122.00  2011
# 2   6900 160.00  2011
# 3   6950 110.00  2011
# 4   6950 156.00  2011
# 5   6950  99.00  2011
# 6   6970 131.00  2011
# 7   6972 116.00  2011
# 8   6980 150.00  2011
# 9   6990  86.00  2011

# %%
cars.tail(10)
# Out:
#        mileage     make  model               fuel    gear       offerType  \
# 46395       10  Citroen     C1           Gasoline  Manual  Pre-registered
# 46396       99     Fiat    500  Electric/Gasoline  Manual  Pre-registered
# 46397      550     Fiat    500  Electric/Gasoline  Manual   Demonstration
# 46398      837     Fiat  Panda  Electric/Gasoline  Manual   Demonstration
# 46399     1500    Skoda  Fabia           Gasoline  Manual   Demonstration
# 46400       99     Fiat    500  Electric/Gasoline  Manual  Pre-registered
# 46401       99     Fiat    500  Electric/Gasoline  Manual  Pre-registered
# 46402       99     Fiat    500  Electric/Gasoline  Manual  Pre-registered
# 46403       99     Fiat    500  Electric/Gasoline  Manual  Pre-registered
# 46404       99     Fiat    500  Electric/Gasoline  Manual  Pre-registered
#
#        price    hp  year
# 46395  12340 72.00  2021
# 46396  12490 71.00  2021
# 46397  12805 69.00  2021
# 46398  12805 69.00  2021
# 46399  12980 60.00  2021
# 46400  12990 71.00  2021
# 46401  12990 71.00  2021
# 46402  12990 71.00  2021
# 46403  12990 71.00  2021
# 46404  12990 71.00  2021

# %%
# Checking null values

cars.isnull().sum()
# Out:
# mileage        0
# make           0
# model        143
# fuel           0
# gear         182
# offerType      0
# price          0
# hp            29
# year           0
# dtype: int64

# %% [markdown]
# There are missing values in columns "model",  "gear" and "hp". It should be fixed.

# %%
# Check datatypes

cars.dtypes
# Out:
# mileage        int64
# make          object
# model         object
# fuel          object
# gear          object
# offerType     object
# price          int64
# hp           float64
# year           int64
# dtype: object

# %%
# Descriptive statictics

pd.set_option('display.float_format', lambda x: '%.2f' % x)
cars[['mileage', 'price', 'hp']].describe()
# Out:
#          mileage      price       hp
# count   46405.00   46405.00 46376.00
# mean    71177.86   16572.34   132.99
# std     62625.31   19304.70    75.45
# min         0.00    1100.00     1.00
# 25%     19800.00    7490.00    86.00
# 50%     60000.00   10999.00   116.00
# 75%    105000.00   19490.00   150.00
# max   1111111.00 1199900.00   850.00

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46405 entries, 0 to 46404
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   mileage    46405 non-null  int64
#  1   make       46405 non-null  object
#  2   model      46262 non-null  object
#  3   fuel       46405 non-null  object
#  4   gear       46223 non-null  object
#  5   offerType  46405 non-null  object
#  6   price      46405 non-null  int64
#  7   hp         46376 non-null  float64
#  8   year       46405 non-null  int64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 3.2+ MB

# %% [markdown]
# <b>Data cleaning: </b>

# %%
#create dataframe with missing values

missing = cars.isnull()
missing.head(10)
# Out:
#    mileage   make  model   fuel   gear  offerType  price     hp   year
# 0    False  False  False  False  False      False  False  False  False
# 1    False  False  False  False  False      False  False  False  False
# 2    False  False  False  False  False      False  False  False  False
# 3    False  False  False  False  False      False  False  False  False
# 4    False  False  False  False  False      False  False  False  False
# 5    False  False  False  False  False      False  False  False  False
# 6    False  False  False  False  False      False  False  False  False
# 7    False  False  False  False  False      False  False  False  False
# 8    False  False  False  False  False      False  False  False  False
# 9    False  False  False  False  False      False  False  False  False

# %%
# Find average hp and replace missing values

avg_hp = cars['hp'].mean(axis = 0)
avg_hp
# Out:
# 132.99098671726756

# %%
cars['hp'].replace(np.nan, avg_hp, inplace = True)
cars['hp'].isnull().sum()
# Out:
# <ipython-input-61-ff033a432b11>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   cars['hp'].replace(np.nan, avg_hp, inplace = True)
# 0

# %%
cars.loc[cars['model'].isna()]
# Out:
#        mileage    make model               fuel       gear       offerType  \
# 365       3500  Others   NaN           Electric     Manual            Used
# 2001      2900  Others   NaN           Electric  Automatic            Used
# 2009     60866    Opel   NaN           Gasoline     Manual            Used
# 2019      3550    Opel   NaN           Gasoline     Manual            Used
# 2496      3000    Audi   NaN           Electric  Automatic   Demonstration
# ...        ...     ...   ...                ...        ...             ...
# 46074        1  Others   NaN           Gasoline     Manual  Pre-registered
# 46102        1  Others   NaN           Gasoline     Manual  Pre-registered
# 46114       35     Kia   NaN  Electric/Gasoline  Automatic  Pre-registered
# 46120       35     Kia   NaN           Electric  Automatic  Pre-registered
# 46237     2000   Tesla   NaN           Electric  Automatic            Used
#
#         price     hp  year
# 365      5500  38.00  2018
# 2001     7900   5.00  2018
# 2009    12290  82.00  2019
# 2019    15800 110.00  2019
# 2496   172450 598.00  2021
# ...       ...    ...   ...
# 46074   23990 150.00  2021
# 46102   23990 150.00  2021
# 46114   30440 141.00  2021
# 46120   32440 204.00  2021
# 46237   57020 487.00  2021
#
# [143 rows x 9 columns]

# %%
# Drop rows with NaN value in model column

cars.dropna(subset = ["model"], axis = 0, inplace = True)
cars.reset_index(drop = True, inplace = True)

# %%
# Finding most frequent gear value replace missing values

cars['gear'].value_counts().idxmax()
# Out:
# 'Manual'

# %%
cars['gear'].replace(np.nan, "Manual", inplace = True)
# Out:
# <ipython-input-65-76f156f73ab3>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   cars['gear'].replace(np.nan, "Manual", inplace = True)

# %%
# Also check fuel column
cars['fuel'].unique()
# Out:
# array(['Diesel', 'Gasoline', 'Electric/Gasoline', '-/- (Fuel)',
#        'Electric', 'Electric/Diesel', 'CNG', 'LPG', 'Others', 'Hydrogen',
#        'Ethanol'], dtype=object)

# %% [markdown]
# '-/- (Fuel)' value in the 'fuel' column should be replaced.

# %%
# Find most frequent value and replace

cars['gear'].value_counts().idxmax()

cars['fuel'].replace('-/- (Fuel)', 'Gasoline', inplace = True)
# Out:
# <ipython-input-67-d4cf32182e71>:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   cars['fuel'].replace('-/- (Fuel)', 'Gasoline', inplace = True)

# %%
# We have seen in descriptive statistics that min value of hp is 1. That can't be true, we should replase it.

cars.loc[cars['hp'] == 1]
# Out:
#        mileage     make   model               fuel    gear offerType  price  \
# 9091    167000  Renault  Megane             Diesel  Manual      Used   5450
# 36106   302000   Toyota  Prius+  Electric/Gasoline  Manual      Used   7985
#
#         hp  year
# 9091  1.00  2012
# 36106 1.00  2013

# %%
cars[['hp']].loc[(cars['model'] == 'Megane') & (cars['year'] == 2012)].mean()
# Out:
# hp   110.61
# dtype: float64

# %%
cars[['year', 'hp']].loc[(cars['model'] == 'Prius')].mean()
# Out:
# year   2013.69
# hp      107.21
# dtype: float64

# %%
# replace hp 1 values with 110
cars['hp'].replace(1, 110, inplace = True)
cars.loc[(cars['model'] == 'Megane') & (cars['year'] == 2012)]
# Out:
# <ipython-input-71-f79828789e42>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   cars['hp'].replace(1, 110, inplace = True)
#        mileage     make   model      fuel       gear offerType  price     hp  \
# 3805    170000  Renault  Megane  Gasoline     Manual      Used   5000 131.00
# 4021    112800  Renault  Megane  Gasoline     Manual      Used   4800 101.00
# 4026     72450  Renault  Megane  Gasoline     Manual      Used   4888 116.00
# 7187    110000  Renault  Megane  Gasoline     Manual      Used   5499 101.00
# 9091    167000  Renault  Megane    Diesel     Manual      Used   5450 110.00
# 9470    101111  Renault  Megane  Gasoline     Manual      Used   5990 110.00
# 9476    148401  Renault  Megane    Diesel     Manual      Used   5990 106.00
# 11163   111000  Renault  Megane    Diesel     Manual      Used   5999 106.00
# 11574   101362  Renault  Megane  Gasoline  Automatic      Used   8750 140.00
# 12451   124000  Renault  Megane    Diesel     Manual      Used   5750 106.00
# 14995   147000  Renault  Megane    Diesel     Manual      Used   9500 131.00
# 15627   110000  Renault  Megane  Gasoline     Manual      Used   6099 110.00
# 21314    86252  Renault  Megane  Gasoline     Manual      Used   9490 179.00
# 23652   132000  Renault  Megane    Diesel     Manual      Used   4999 110.00
# 24919   242606  Renault  Megane    Diesel     Manual      Used   4349 110.00
# 26614   136000  Renault  Megane  Gasoline     Manual      Used   4800 101.00
# 26622   149000  Renault  Megane  Gasoline     Manual      Used   4950 101.00
# 28695   115282  Renault  Megane  Gasoline     Manual      Used   6490 116.00
# 28913    87061  Renault  Megane  Gasoline     Manual      Used   6499 101.00
# 30410    77000  Renault  Megane    Diesel     Manual      Used   7000 110.00
# 32537   130000  Renault  Megane  Gasoline     Manual      Used   4690 101.00
# 32757   150000  Renault  Megane    Diesel     Manual      Used   4399 106.00
# 33177   165000  Renault  Megane    Diesel     Manual      Used   4650 131.00
# 35117    66421  Renault  Megane  Gasoline     Manual      Used   7390 116.00
# 35195   115000  Renault  Megane    Diesel     Manual      Used   5999 106.00
# 35253    81927  Renault  Megane  Gasoline     Manual      Used   6480 101.00
# 35299    88890  Renault  Megane    Diesel     Manual      Used   8450 160.00
# 35374    60200  Renault  Megane  Gasoline     Manual      Used   6850 110.00
# 35492   116394  Renault  Megane    Diesel  Automatic      Used   6999 110.00
# 35544   117000  Renault  Megane    Diesel     Manual      Used   5690  90.00
# 35551    67368  Renault  Megane  Gasoline     Manual      Used   6700 101.00
# 35567   146999  Renault  Megane  Gasoline     Manual      Used   5690 101.00
# 35702   210000  Renault  Megane    Diesel     Manual      Used   3700 110.00
# 35785   113220  Renault  Megane  Gasoline  Automatic      Used   8900 140.00
# 35832   110000  Renault  Megane  Gasoline     Manual      Used   4900 101.00
# 35938    77200  Renault  Megane  Gasoline     Manual      Used   5780 101.00
# 35990   110000  Renault  Megane  Gasoline     Manual      Used   5900 116.00
# 36003   157248  Renault  Megane    Diesel     Manual      Used   4600 110.00
# 36022    77500  Renault  Megane  Gasoline     Manual      Used   7390 116.00
# 36057   104000  Renault  Megane    Diesel     Manual      Used   6340  90.00
# 36066   137000  Renault  Megane    Diesel     Manual      Used   4950 131.00
#
#        year
# 3805   2012
# 4021   2012
# 4026   2012
# 7187   2012
# 9091   2012
# 9470   2012
# 9476   2012
# 11163  2012
# 11574  2012
# 12451  2012
# 14995  2012
# 15627  2012
# 21314  2012
# 23652  2012
# 24919  2012
# 26614  2012
# 26622  2012
# 28695  2012
# 28913  2012
# 30410  2012
# 32537  2012
# 32757  2012
# 33177  2012
# 35117  2012
# 35195  2012
# 35253  2012
# 35299  2012
# 35374  2012
# 35492  2012
# 35544  2012
# 35551  2012
# 35567  2012
# 35702  2012
# 35785  2012
# 35832  2012
# 35938  2012
# 35990  2012
# 36003  2012
# 36022  2012
# 36057  2012
# 36066  2012

# %%
cars[['mileage', 'price', 'hp']].describe()
# Out:
#          mileage      price       hp
# count   46262.00   46262.00 46262.00
# mean    71259.64   16544.75   132.89
# std     62635.20   19253.64    75.01
# min         0.00    1100.00     5.00
# 25%     19900.00    7490.00    86.00
# 50%     60000.00   10999.00   116.00
# 75%    105000.00   19483.75   150.00
# max   1111111.00 1199900.00   850.00

# %% [markdown]
# Now we can see that the minimum HP value is 5. Let's investigate it.

# %%
cars.loc[cars['hp'] == 850]
# Out:
#        mileage           make     model      fuel       gear offerType  \
# 43013     9234  Mercedes-Benz  G 63 AMG  Gasoline  Automatic      Used
#
#         price     hp  year
# 43013  216619 850.00  2019

# %% [markdown]
# That's true, Microcar Doe has 5 horsepower. Let's go further.

# %%
cars.isnull().sum()
# Out:
# mileage      0
# make         0
# model        0
# fuel         0
# gear         0
# offerType    0
# price        0
# hp           0
# year         0
# dtype: int64

# %%
# set year column datatype as object

cars[["year"]] = cars[["year"]].astype('object')

# %% [markdown]
# <b>Start our analysis with visualizations:</b>

# %% [markdown]
# Let's have a look at how horsepower is distributed among all cars:

# %%
import matplotlib as plt
from matplotlib import pyplot
plt.pyplot.hist(cars['hp'])

plt.pyplot.xlabel('horsepower')
plt.pyplot.ylabel('count')
plt.pyplot.title('Horsepower bins')
# Out:
# Text(0.5, 1.0, 'Horsepower bins')

# %% [markdown]
# According to the descriptive statistics, 75% of all cars have less than 150 horsepower. 25% is between 150 and 850. Here we have huge outliers.

# %% [markdown]
# We can also represent data about horsepower like this:

# %%
# divide cars into 4 groups of horsepower

groups = np.array([1., 100., 200., 400., 850.])
group_names = ['5-100 hp', '100-200 hp', '200-400 hp', '400 + hp']
cars['hp-bin'] = pd.cut(cars['hp'], groups, labels = group_names, include_lowest = True)
cars[['hp', 'hp-bin']].head(10)
# Out:
#       hp      hp-bin
# 0 116.00  100-200 hp
# 1 122.00  100-200 hp
# 2 160.00  100-200 hp
# 3 110.00  100-200 hp
# 4 156.00  100-200 hp
# 5  99.00    5-100 hp
# 6 131.00  100-200 hp
# 7 116.00  100-200 hp
# 8 150.00  100-200 hp
# 9  86.00    5-100 hp

# %%
cars.loc[cars['hp-bin'] == '5-100 hp']
# Out:
#        mileage        make             model               fuel       gear  \
# 5       147000      Toyota             Auris  Electric/Gasoline  Automatic
# 9          104        Ford           Transit             Diesel     Manual
# 15       72000  Volkswagen              Polo           Gasoline     Manual
# 20       44800         Kia           Picanto           Gasoline  Automatic
# 32      128000        MINI  One D Countryman             Diesel     Manual
# ...        ...         ...               ...                ...        ...
# 46257       99        Fiat               500  Electric/Gasoline     Manual
# 46258       99        Fiat               500  Electric/Gasoline     Manual
# 46259       99        Fiat               500  Electric/Gasoline     Manual
# 46260       99        Fiat               500  Electric/Gasoline     Manual
# 46261       99        Fiat               500  Electric/Gasoline     Manual
#
#             offerType  price    hp  year    hp-bin
# 5                Used   6950 99.00  2011  5-100 hp
# 9                Used   6990 86.00  2011  5-100 hp
# 15               Used   6999 60.00  2011  5-100 hp
# 20               Used   7850 86.00  2012  5-100 hp
# 32               Used   7990 90.00  2012  5-100 hp
# ...               ...    ...   ...   ...       ...
# 46257  Pre-registered  12990 71.00  2021  5-100 hp
# 46258  Pre-registered  12990 71.00  2021  5-100 hp
# 46259  Pre-registered  12990 71.00  2021  5-100 hp
# 46260  Pre-registered  12990 71.00  2021  5-100 hp
# 46261  Pre-registered  12990 71.00  2021  5-100 hp
#
# [16764 rows x 10 columns]

# %%
pie1 = cars.groupby(['hp-bin']).count()
plot = pie1.plot.pie(y = 'hp', title="Horsepower distribution among all offers", legend=False,
                   autopct='%1.1f%%', colors = ['#d9f852', '#4a1be4', '#95928c', '#ffffff'],
                   shadow=True, startangle=150)
# Out:
# <ipython-input-79-8ab02fda012c>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   pie1 = cars.groupby(['hp-bin']).count()

# %%
# Let's make price bins and a pie chart

groups1 = np.array([1., 10000., 20000., 50000., 2000000.])
group_names1 = ['< 10000€', '10000-20000€', '20000-50000€', '50000€ +',]
cars['price-bin'] = pd.cut(cars['price'], groups1, labels = group_names1, include_lowest = True)
cars[['price', 'price-bin']].head(10)
# Out:
#    price price-bin
# 0   6800  < 10000€
# 1   6877  < 10000€
# 2   6900  < 10000€
# 3   6950  < 10000€
# 4   6950  < 10000€
# 5   6950  < 10000€
# 6   6970  < 10000€
# 7   6972  < 10000€
# 8   6980  < 10000€
# 9   6990  < 10000€

# %%
pie_price_bins = cars.groupby(['price-bin']).count()
plot = pie_price_bins.plot.pie(y = 'price', title="Price groups ratio", legend=False,
                   autopct='%1.1f%%', colors = ['#d9f852', '#4a1be4', '#95928c', '#ffffff'],
                   shadow=True, startangle=150)
# Out:
# <ipython-input-81-b0236c532cda>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   pie_price_bins = cars.groupby(['price-bin']).count()

# %%
cars['price-bin'].value_counts()
# Out:
# price-bin
# < 10000€        20664
# 10000-20000€    14770
# 20000-50000€     9371
# 50000€ +         1457
# Name: count, dtype: int64

# %% [markdown]
# 44.7% of all AutoScaut24 offers have prices less than 10,000 euros.

# %%
# Check gear type ratio

import matplotlib.pyplot as plt

pie_gear = cars.groupby(['gear']).count()
plot_gear = pie_gear.plot.pie(y = 'model', title="Gear type ratio", legend=False,
                   autopct='%1.1f%%', colors = ['#4a1be4', '#d9f852', '#95928c'],
                   shadow=True, startangle=35)
# draw circle
centre_circle = plt.Circle((0, 0), 0.70, fc='white')
fig = plt.gcf()

# Add circle to the pie chart
fig.gca().add_artist(centre_circle)

# %%
cars['gear'].value_counts()
# Out:
# gear
# Manual            30492
# Automatic         15714
# Semi-automatic       56
# Name: count, dtype: int64

# %%
# Check fuel type value_counts
cars['fuel'].value_counts()
# Out:
# fuel
# Gasoline             28822
# Diesel               15220
# Electric/Gasoline     1150
# Electric               725
# LPG                    126
# CNG                    116
# Electric/Diesel         53
# Others                  47
# Ethanol                  2
# Hydrogen                 1
# Name: count, dtype: int64

# %%
cars.loc[cars['fuel'] == 'Others']
# Out:
#        mileage        make         model    fuel       gear       offerType  \
# 2994     50150      Toyota       Verso-S  Others     Manual            Used
# 3126        49        Fiat           500  Others     Manual  Pre-registered
# 4504     53750     Hyundai           i10  Others     Manual            Used
# 4505     53750     Hyundai           i10  Others     Manual            Used
# 4849       800        Fiat           500  Others     Manual  Pre-registered
# 4857        49        Fiat           500  Others     Manual  Pre-registered
# 5207     43400      Toyota          Aygo  Others     Manual            Used
# 6529      1500     Renault          Clio  Others     Manual   Demonstration
# 7206    119076     Renault          Clio  Others     Manual            Used
# 8070     87051      Toyota         Yaris  Others  Automatic            Used
# 8918    129000     Peugeot           208  Others     Manual            Used
# 11767       12     Hyundai           i20  Others     Manual  Pre-registered
# 13246     1250     Renault          Clio  Others     Manual  Pre-registered
# 13494    28290  Volkswagen          Polo  Others  Automatic            Used
# 13758    60000  Volkswagen  Golf Variant  Others     Manual            Used
# 14492    21217        Opel         Astra  Others     Manual            Used
# 14499    13716        Opel         Corsa  Others     Manual            Used
# 16004       10      Toyota          Aygo  Others     Manual  Pre-registered
# 16198    28071        Opel       Mokka X  Others     Manual            Used
# 16604    36479      Toyota         Yaris  Others  Automatic            Used
# 16717    66558        Ford         Focus  Others     Manual            Used
# 18204   114500      Toyota       Avensis  Others     Manual            Used
# 19456    48700        Opel         Mokka  Others     Manual            Used
# 19528    28071        Opel       Mokka X  Others     Manual            Used
# 19614   206000         BMW           320  Others     Manual            Used
# 19838    68650      Toyota         Verso  Others     Manual            Used
# 20525    82918       Volvo           V60  Others  Automatic            Used
# 23994    89733        Audi            A4  Others  Automatic            Used
# 29394    55000      Toyota         Auris  Others     Manual            Used
# 31726   113962        Ford         Focus  Others     Manual            Used
# 31850     1500      Toyota    Highlander  Others  Automatic   Demonstration
# 31857       49        Fiat           500  Others     Manual  Pre-registered
# 33511    42450      Toyota          Aygo  Others     Manual            Used
# 33562       10      Toyota          Aygo  Others     Manual  Pre-registered
# 40731    34317     Renault        Twingo  Others     Manual   Demonstration
# 42203    50946     Renault           ZOE  Others  Automatic            Used
# 42277    45502        Opel         Astra  Others     Manual            Used
# 42307    21990        SEAT           Mii  Others     Manual            Used
# 42511    47999     Renault        Koleos  Others     Manual   Demonstration
# 43191    27000        SEAT         Ibiza  Others     Manual            Used
# 43276     1590     Renault          Clio  Others     Manual   Demonstration
# 43568    17386       Skoda       Octavia  Others  Automatic            Used
# 43801     6757        Audi            A5  Others  Automatic            Used
# 43833    41948       Skoda        Kodiaq  Others  Automatic            Used
# 44739     1873        Fiat          500C  Others     Manual            Used
# 45394       10     Renault          Clio  Others     Manual   Demonstration
# 45398       10     Renault          Clio  Others     Manual   Demonstration
#
#        price     hp  year      hp-bin     price-bin
# 2994    9450  99.00  2015    5-100 hp      < 10000€
# 3126   14190  69.00  2021    5-100 hp  10000-20000€
# 4504    6880  69.00  2014    5-100 hp      < 10000€
# 4505    6880  69.00  2014    5-100 hp      < 10000€
# 4849   14490  69.00  2021    5-100 hp  10000-20000€
# 4857   14989  69.00  2021    5-100 hp  10000-20000€
# 5207    8584  72.00  2018    5-100 hp      < 10000€
# 6529   15580  72.00  2021    5-100 hp  10000-20000€
# 7206    5990  73.00  2013    5-100 hp      < 10000€
# 8070   10200 101.00  2014  100-200 hp  10000-20000€
# 8918    6750  82.00  2014    5-100 hp      < 10000€
# 11767  13990  84.00  2021    5-100 hp  10000-20000€
# 13246  16990  91.00  2021    5-100 hp  10000-20000€
# 13494  12990  90.00  2012    5-100 hp  10000-20000€
# 13758  12950 110.00  2015  100-200 hp  10000-20000€
# 14492  15790 105.00  2019  100-200 hp  10000-20000€
# 14499  15945 101.00  2020  100-200 hp  10000-20000€
# 16004   9960  72.00  2021    5-100 hp      < 10000€
# 16198  15990 140.00  2019  100-200 hp  10000-20000€
# 16604  13590 101.00  2018  100-200 hp  10000-20000€
# 16717  10880 125.00  2013  100-200 hp  10000-20000€
# 18204   8900 147.00  2012  100-200 hp      < 10000€
# 19456  14290 140.00  2015  100-200 hp  10000-20000€
# 19528  15990 140.00  2019  100-200 hp  10000-20000€
# 19614   6900 163.00  2012  100-200 hp      < 10000€
# 19838  11550 147.00  2012  100-200 hp  10000-20000€
# 20525  16500 150.00  2016  100-200 hp  10000-20000€
# 23994  23980 170.00  2018  100-200 hp  20000-50000€
# 29394  11760 116.00  2016  100-200 hp  10000-20000€
# 31726   7990 101.00  2015  100-200 hp      < 10000€
# 31850  56990 247.00  2021  200-400 hp      50000€ +
# 31857  14490  69.00  2021    5-100 hp  10000-20000€
# 33511   7900  69.00  2018    5-100 hp      < 10000€
# 33562  10550  72.00  2021    5-100 hp  10000-20000€
# 40731   8990  90.00  2017    5-100 hp      < 10000€
# 42203  12990  92.00  2018    5-100 hp  10000-20000€
# 42277  13590 125.00  2018  100-200 hp  10000-20000€
# 42307   8229  68.00  2018    5-100 hp      < 10000€
# 42511  23790 177.00  2018  100-200 hp  20000-50000€
# 43191   8950  90.00  2019    5-100 hp      < 10000€
# 43276  13190  90.00  2019    5-100 hp  10000-20000€
# 43568  18290 131.00  2019  100-200 hp  10000-20000€
# 43801  30937 170.00  2019  100-200 hp  20000-50000€
# 43833  32990 190.00  2019  100-200 hp  20000-50000€
# 44739  15900  71.00  2020    5-100 hp  10000-20000€
# 45394  15555 101.00  2021  100-200 hp  10000-20000€
# 45398  15777 101.00  2021  100-200 hp  10000-20000€

# %% [markdown]
# Some fuel-related data is useless because it provides insufficient information for analysis and visualization. We can use grouping.

# %%
# Rename LPG CNG Ethanol Hydrogen with Gas

cars['fuel_group'] = cars['fuel']
cars['fuel_group'].replace('LPG', 'Gas', inplace = True)
cars['fuel_group'].replace('CNG', 'Gas', inplace = True)
cars['fuel_group'].replace('Ethanol', 'Gas', inplace = True)
cars['fuel_group'].replace('Hydrogen', 'Gas', inplace = True)
# Out:
# <ipython-input-87-68ff40bea9d2>:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   cars['fuel_group'].replace('LPG', 'Gas', inplace = True)
# <ipython-input-87-68ff40bea9d2>:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   cars['fuel_group'].replace('CNG', 'Gas', inplace = True)
# <ipython-input-87-68ff40bea9d2>:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   cars['fuel_group'].replace('Ethanol', 'Gas', inplace = True)
# <ipython-input-87-68ff40bea9d2>:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   cars['fuel_group'].replace('Hydrogen', 'Gas', inplace = True)

# %% [markdown]
# Checking information about models of cars that have "Other" fuel types, we can find out that almost all of them may possibly have gasoline fuel types.

# %%
# Replace 'Others' value with 'Gasoline'

cars['fuel_group'].replace('Others', 'Gasoline', inplace = True)
# Out:
# <ipython-input-88-50e61af19b2d>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   cars['fuel_group'].replace('Others', 'Gasoline', inplace = True)

# %%
# Group 'Electric/Gasoline' and 'Electric/Diesel' into 'Hybrid'

cars['fuel_group'].replace('Electric/Gasoline', 'Hybrid', inplace = True)
cars['fuel_group'].replace('Electric/Diesel', 'Hybrid', inplace = True)
# Out:
# <ipython-input-89-adae8fcc14c3>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   cars['fuel_group'].replace('Electric/Gasoline', 'Hybrid', inplace = True)
# <ipython-input-89-adae8fcc14c3>:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   cars['fuel_group'].replace('Electric/Diesel', 'Hybrid', inplace = True)

# %%
cars['fuel_group'].value_counts()
# Out:
# fuel_group
# Gasoline    28869
# Diesel      15220
# Hybrid       1203
# Electric      725
# Gas           245
# Name: count, dtype: int64

# %%
# Create fuel type pie chart

plt.rcParams['font.size'] = 10
pf = cars.loc[cars['fuel_group'] != 'Gas']
pie_fuel = pf.groupby(['fuel_group']).count()
plot = pie_fuel.plot.pie(y = 'fuel', title="Fuel types ratio", legend=False,
                   autopct='%1.1f%%', colors = ['#d9f852', '#95928c', '#4a1be4' , '#ffffff'],
                   shadow=True, startangle=150)

# %% [markdown]
# Let's investigate offer type column:

# %%
cars['offerType'].value_counts()
# Out:
# offerType
# Used              39997
# Pre-registered     2773
# Demonstration      2360
# Employee's car     1119
# New                  13
# Name: count, dtype: int64

# %% [markdown]
# No surprises; almost all offer types are 'Used'. We can also group values in a column to check the ratio between New and Used cars.

# %%
# add 'Pre-registered' 'Demonstration' into 'New'

cars['new/used'] = cars['offerType']
cars['new/used'].replace('Pre-registered', 'New', inplace = True)
cars['new/used'].replace('Demonstration', 'New', inplace = True)

# add 'Employee's car' into 'Used'
cars['new/used'].replace("Employee's car", 'Used', inplace = True)
# Out:
# <ipython-input-93-49cb200af8f6>:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   cars['new/used'].replace('Pre-registered', 'New', inplace = True)
# <ipython-input-93-49cb200af8f6>:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   cars['new/used'].replace('Demonstration', 'New', inplace = True)
# <ipython-input-93-49cb200af8f6>:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   cars['new/used'].replace("Employee's car", 'Used', inplace = True)

# %%
cars['new/used'].value_counts()
# Out:
# new/used
# Used    41116
# New      5146
# Name: count, dtype: int64

# %%
# Create pie chart with ratio of New and Used car offers

plt.rcParams['font.size'] = 12

pyplot.bar(cars['new/used'].unique(), cars['new/used'].value_counts(), color = '#4a1be4')

pyplot.ylabel('number of vehicles')
pyplot.title('Novelty bars')
# Out:
# Text(0.5, 1.0, 'Novelty bars')

# %% [markdown]
# <b>Statistical analysis:</b>

# %% [markdown]
# Now we are going to check some relationships between numeric variables.

# %%
# Select only the numeric columns from the 'cars' DataFrame
numeric_columns = cars.select_dtypes(include=[np.number])

# Calculate the correlation matrix
correlation_matrix = numeric_columns.corr()

# Display the correlation matrix
print(correlation_matrix)
# Out:
#          mileage  price    hp
# mileage     1.00  -0.30 -0.01
# price      -0.30   1.00  0.75
# hp         -0.01   0.75  1.00

# %%
from scipy import stats
pearson_coef, p_value = stats.pearsonr(cars['price'], cars['mileage'])
print('The Pearson correlation is', pearson_coef, 'p-value is', p_value)
# Out:
# The Pearson correlation is -0.30290556073430497 p-value is 0.0

# %%
pearson_coef1, p_value1 = stats.pearsonr(cars['year'], cars['mileage'])
print('The Pearson correlation is', pearson_coef1, 'p-value is', p_value1)
# Out:
# The Pearson correlation is -0.676106819770153 p-value is 0.0

# %%
pearson_coef2, p_value2 = stats.pearsonr(cars['price'], cars['year'])
print('The Pearson correlation is', pearson_coef2, 'p-value is', p_value2)
# Out:
# The Pearson correlation is 0.40595583237406596 p-value is 0.0

# %%
gear_test = cars[['gear', 'model', 'price']]
pricegear_test = gear_test[['gear', 'price']].groupby(['gear'])

pricegear_test.head(2)
# Out:
#                gear  price
# 0            Manual   6800
# 1            Manual   6877
# 5         Automatic   6950
# 8         Automatic   6980
# 901  Semi-automatic   9780
# 902  Semi-automatic   9780

# %%
gear_test
# Out:
#          gear   model  price
# 0      Manual     316   6800
# 1      Manual    Golf   6877
# 2      Manual    Exeo   6900
# 3      Manual  Megane   6950
# 4      Manual     308   6950
# ...       ...     ...    ...
# 46257  Manual     500  12990
# 46258  Manual     500  12990
# 46259  Manual     500  12990
# 46260  Manual     500  12990
# 46261  Manual     500  12990
#
# [46262 rows x 3 columns]

# %%
pricegear_test.get_group('Manual')['price']
# Out:
# <ipython-input-102-be8395121934>:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   pricegear_test.get_group('Manual')['price']
# 0         6800
# 1         6877
# 2         6900
# 3         6950
# 4         6950
#          ...
# 46257    12990
# 46258    12990
# 46259    12990
# 46260    12990
# 46261    12990
# Name: price, Length: 30492, dtype: int64

# %% [markdown]
# Very high f -value, p-value < 0.001. Correlation between gear type and price is statistically significant.

# %%
f_val, p_val = stats.f_oneway(pricegear_test.get_group('Manual')['price'], pricegear_test.get_group('Automatic')['price'])

print('Anova results: f = ', f_val, ', p = ', p_val)
# Out:
# Anova results: f =  10635.900231397447 , p =  0.0
# <ipython-input-103-66440f6a90de>:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   f_val, p_val = stats.f_oneway(pricegear_test.get_group('Manual')['price'], pricegear_test.get_group('Automatic')['price'])

# %% [markdown]
# Strong correlation too.

# %%
f_val, p_val = stats.f_oneway(pricegear_test.get_group('Manual')['price'], pricegear_test.get_group('Semi-automatic')['price'])

print('Anova results: f = ', f_val, ', p = ', p_val)
# Out:
# Anova results: f =  5.703817139510052 , p =  0.016934095527232778
# <ipython-input-104-d4e397fb28da>:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   f_val, p_val = stats.f_oneway(pricegear_test.get_group('Manual')['price'], pricegear_test.get_group('Semi-automatic')['price'])

# %% [markdown]
# F-value is not high, p > 0.001. No strong correlation.

# %%
f_val, p_val = stats.f_oneway(pricegear_test.get_group('Automatic')['price'], pricegear_test.get_group('Semi-automatic')['price'])

print('Anova results: f = ', f_val, ', p = ', p_val)
# Out:
# Anova results: f =  27.278758841863247 , p =  1.7837561625754947e-07
# <ipython-input-105-40f7c6109668>:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   f_val, p_val = stats.f_oneway(pricegear_test.get_group('Automatic')['price'], pricegear_test.get_group('Semi-automatic')['price'])

# %% [markdown]
# Here we can see correlation to. We can note that 'Manual' and 'Semi-autmatic' gear types are not strongly correlated with one another.

# %%
# Create a scatterplot that show price by hp distribution

sns.regplot(x='hp', y = 'price', data = cars, color = '#4a1be4')
plt.ylim(0,)
# Out:
# (0.0, 1260346.9241547054)

# %%
sns.regplot(x='hp', y = 'price', data = cars, color = '#4a1be4')
plt.ylim(0,400000)
# Out:
# (0.0, 400000.0)

# %% [markdown]
# There is a correlation coefficient of 0.75 between horsepower and price. Also, there is a high probability of price outliers when the horsepower value is higher than 450.

# %% [markdown]
# Now we are going to check how fuel types are represented in cars produced in different years.

# %% [markdown]
# <b>Let's continue our visualizations and analysis:</b>

# %%
# Create fuel type by year line charts

fuel_count = cars.groupby(['year', 'fuel_group'], as_index = False).count()
fuel_count
gasoline = fuel_count[(fuel_count['fuel_group'] == 'Gasoline')]
diesel = fuel_count[(fuel_count['fuel_group'] == 'Diesel')]
hybrid = fuel_count[(fuel_count['fuel_group'] == 'Hybrid')]
gas = fuel_count[(fuel_count['fuel_group'] == 'Gas')]
electric = fuel_count[(fuel_count['fuel_group'] == 'Electric')]

plt.plot(gasoline['year'], gasoline['make'], label = 'Gasoline', color = '#4a1be4')
plt.plot(diesel['year'], diesel['make'], label = 'Diesel', color = '#d9f852')
plt.legend()
plt.title('Fuel type of cars by year')
plt.ylim(350,)
# Out:
# (350.0, 3221.0)

# %%
plt.plot(hybrid['year'], hybrid['make'], label = 'Hybrid', color = '#4a1be4')
plt.plot(electric['year'], electric['make'], label = 'Electric', color = '#d9f852')
plt.plot(gas['year'], gas['make'], label = 'Gas', color = '#95928c')
plt.legend()
plt.title('Fuel type of cars by year')
plt.ylim(0,)
# Out:
# (0.0, 435.55)

# %% [markdown]
# Quantity of diesel cars that people sell on AutoScaut2024 has the highest value in 2017. At the same time, gasoline car quantity is at its lowest. The line representing the number of gasoline cars has a downtrend until 2017 and an uptrend from 2017 to 2021. The line representing the number of diesel cars has an uptrend until 2017 and a strong decrease between 2017 and 2021:  diesel cars produced in 2021, will be 4 times less than those produced in 2017. The number of electric and hybrid vehicles represented increases with the year of manufacture. Gas cars are scarce, the trend is flat, and their quantity does not tend to increase or decrease significantly over production years.

# %%
plt.rcParams['font.size'] = 10
gear_count = cars.groupby(['year', 'gear'], as_index = False).count()
X = gear_count['year'].unique()
manual = gear_count[(gear_count['gear'] == 'Manual')]
automatic = gear_count[(gear_count['gear'] == 'Automatic')]

X_axis = np.arange(len(X))

plt.bar(X_axis - 0.1, manual['make'], 0.3, label = 'Manual', color = '#d9f852')
plt.bar(X_axis + 0.2, automatic['make'], 0.3, label = 'Automatic', color = '#4a1be4')

plt.xticks(X_axis, X)
plt.xlabel("Year")
plt.ylabel("Number of cars on AutoScaut24")
plt.title("Gear type by production year")
plt.legend()
plt.show()

# %% [markdown]
# Offers with a production year prior to 2017 have significantly more manual gear types, whereas offers with a production year after 2017 have nearly equal gear types. Automatic gear types were more represented in 2018 and 2020. On this chart, we don't add semi-automatic cars because they are too underrepresented.

# %%
# Create bars that show how price groups are represented by production year

plt.rcParams['font.size'] = 8

import matplotlib.pyplot as plt
import numpy as np

price_bin_year = cars.groupby(['price-bin', 'year'], as_index = False).count()
bin1 = price_bin_year[(price_bin_year['price-bin'] == '< 10000€')]
bin2 = price_bin_year[(price_bin_year['price-bin'] == '10000-20000€')]
bin3 = price_bin_year[(price_bin_year['price-bin'] == '20000-50000€')]
bin4 = price_bin_year[(price_bin_year['price-bin'] == '50000€ +')]

fig, axs = plt.subplots(2, 2)
axs[0, 0].bar(bin1['year'], bin1['make'], label = '< 10000€', color = '#4a1be4')
axs[0, 0].set_title('Price less than 10000€')
axs[1, 0].bar(bin2['year'], bin2['make'], label = '10000-20000€', color = '#4a1be4')
axs[1, 0].set_title('Price 10000-20000€')
axs[1, 0].sharex(axs[0, 0])
axs[0, 1].bar(bin3['year'], bin3['make'], label = '20000-50000€', color = '#4a1be4')
axs[0, 1].set_title('Price 20000-50000€')
axs[1, 1].bar(bin4['year'], bin4['make'], label = '50000€ +', color = '#4a1be4')
axs[1, 1].set_title('Price over 50000€')
fig.tight_layout()
plt.ylim(0,)
# Out:
# <ipython-input-111-4f946db720f6>:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   price_bin_year = cars.groupby(['price-bin', 'year'], as_index = False).count()
# (0.0, 456.75)

# %% [markdown]
# Cars with prices lower than 10,000 euros tend to be less represented when production year increases. And reverce when the price exceeds 10000€.

# %%
plt.rcParams['font.size'] = 8

fuel_ng = cars.loc[cars['fuel_group'] != 'Gas']
price_bin_fuel = fuel_ng.groupby(['price-bin', 'fuel_group'], as_index = False).count()
bin12 = price_bin_fuel[(price_bin_fuel['price-bin'] == '< 10000€')]
bin22 = price_bin_fuel[(price_bin_fuel['price-bin'] == '10000-20000€')]
bin32 = price_bin_fuel[(price_bin_fuel['price-bin'] == '20000-50000€')]
bin42 = price_bin_fuel[(price_bin_fuel['price-bin'] == '50000€ +')]

fig1, axs1 = plt.subplots(2, 2)
axs1[0, 0].pie(bin12['make'], labels = bin12['fuel_group'], autopct='%1.1f%%', colors = ['#d9f852', '#95928c', '#4a1be4' , '#ffffff'], shadow=True, startangle=150, radius=1.1)
axs1[0, 0].set_title('Cars with price less than 10000€')
axs1[0, 1].pie(bin22['make'], labels=bin22['fuel_group'], autopct='%.0f%%', colors = ['#d9f852', '#95928c', '#4a1be4' , '#ffffff'],shadow=True, startangle=150, radius=1.1)
axs1[0, 1].set_title('Cars with price 10000-20000€')
axs1[1, 0].pie(bin32['make'], labels=bin32['fuel_group'], autopct='%1.1f%%', colors = ['#d9f852', '#95928c', '#4a1be4' , '#ffffff'],shadow=True, startangle=150, radius=1.1)
axs1[1, 0].set_title('Cars with price 20000-50000€')
axs1[1, 1].pie(bin42['make'], labels=bin42['fuel_group'], autopct='%.0f%%', colors = ['#d9f852', '#95928c', '#4a1be4' , '#ffffff'], shadow=True,  radius=1.2)
axs1[1, 1].set_title('Cars with price over 50000€')
plt.show()
# Out:
# <ipython-input-112-29a5cfdb9517>:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   price_bin_fuel = fuel_ng.groupby(['price-bin', 'fuel_group'], as_index = False).count()

# %% [markdown]
# Gasoline cars are widely represented (70,4%) among cars with prices lower than 10000 euro. This ratio falls (7.4%) in the next group and falls below half in the next two groups. Another fuel types tends to be more represented in the groups with higher prices. The diesel rate has decreased slightly in the 4th price group.

# %%
fuel_count1 = cars.groupby(['price-bin', 'fuel_group'], as_index = False).count()
fuel_count
gasoline = fuel_count1[(fuel_count1['fuel_group'] == 'Gasoline')]
diesel = fuel_count1[(fuel_count1['fuel_group'] == 'Diesel')]
hybrid = fuel_count1[(fuel_count1['fuel_group'] == 'Hybrid')]
gas = fuel_count1[(fuel_count1['fuel_group'] == 'Gas')]
electric = fuel_count1[(fuel_count1['fuel_group'] == 'Electric')]

plt.plot(gasoline['price-bin'], gasoline['make'], label = 'Gasoline', color = '#4a1be4')
plt.plot(diesel['price-bin'], diesel['make'], label = 'Diesel', color = '#d9f852')
plt.legend()
plt.title('Cars represented by fuel type in price group')
plt.ylabel('Number of offers')
plt.xlabel('Price category')
plt.ylim(0,)
# Out:
# <ipython-input-113-47e9c979e5b5>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   fuel_count1 = cars.groupby(['price-bin', 'fuel_group'], as_index = False).count()
# (0.0, 15147.55)

# %%
plt.plot(hybrid['price-bin'], hybrid['make'], label = 'Hybrid', color = '#4a1be4')
plt.plot(electric['price-bin'], electric['make'], label = 'Electric', color = '#d9f852')
plt.plot(gas['price-bin'], gas['make'], label = 'Gas', color = '#95928c')
plt.legend()
plt.title('Fuel type of cars by year')
plt.ylim(0,)
# Out:
# (0.0, 560.6)

# %% [markdown]
# But looking to the entire population, almost all fuel types, except Hybrid tends to be less reprecented, while price increases.

# %%
# Create bar charts, that show how gear type 'Manual' and 'Automatic' represented in price groups

plt.rcParams['font.size'] = 10

import matplotlib.pyplot as plt
import numpy as np

cars_ma = cars.loc[cars['gear'] != 'Semi-automatic']
price_bin_year1 = cars_ma.groupby(['price-bin', 'gear'], as_index = False).count()
bin11 = price_bin_year1[(price_bin_year1['price-bin'] == '< 10000€')]
bin21 = price_bin_year1[(price_bin_year1['price-bin'] == '10000-20000€')]
bin31 = price_bin_year1[(price_bin_year1['price-bin'] == '20000-50000€')]
bin41 = price_bin_year1[(price_bin_year1['price-bin'] == '50000€ +')]

fig, axs = plt.subplots(2, 2)
axs[0, 0].bar(bin11['gear'], bin11['make'], label = '< 10000€', color = '#4a1be4')
axs[0, 0].set_title('Cars with price less than 10000€')
axs[1, 0].bar(bin21['gear'], bin21['make'], label = '10000-20000€', color = '#4a1be4')
axs[1, 0].set_title('Cars with price 10000-20000€')
axs[1, 0].sharex(axs[0, 0])
axs[0, 1].bar(bin31['gear'], bin31['make'], label = '20000-50000€', color = '#4a1be4')
axs[0, 1].set_title('Cars with price 20000-50000€')
axs[1, 1].bar(bin41['gear'], bin41['make'], label = '50000€ +', color = '#4a1be4')
axs[1, 1].set_title('Cars with price over 50000€')
fig.tight_layout()
plt.ylim(0,)
# Out:
# <ipython-input-115-8da3d9c07ce3>:9: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   price_bin_year1 = cars_ma.groupby(['price-bin', 'gear'], as_index = False).count()
# (0.0, 1479.45)

# %% [markdown]
# Here we can note, that in cars with prices lower than 20,000 euros, manual gear types are more often found. And vice versa if the price is equal to or greater than 20000 euros. The higher the price, the less likely the car has manual gears and reverse for automatic transmission.

# %%
# Create bar charts, that show how gear type 'Semi-automatic' represented in price groups

cars_sa = cars.loc[cars['gear'] == 'Semi-automatic']
price_bin_year12 = cars_sa.groupby(['price-bin', 'gear'], as_index = False).count()

pyplot.plot(price_bin_year12['price-bin'], price_bin_year12['make'], color = '#4a1be4')

pyplot.xlabel('Price category')
pyplot.ylabel('Quantity of cars')
pyplot.title('Semi-Automatic cars in price groups')
plt.ylim(0,)
# Out:
# <ipython-input-116-379548b1e5be>:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   price_bin_year12 = cars_sa.groupby(['price-bin', 'gear'], as_index = False).count()
# (0.0, 50.4)

# %% [markdown]
# Most of all cars, that have Semi-automatic gear are in 1st price group(under 10000€)

# %% [markdown]
# <b> Generating top/stats information: </b>

# %%
# Add columns with value_counts of model and make to dataframe

cars['model_available'] = cars['model'].map(cars['model'].value_counts())
cars['make_count'] = cars['make'].map(cars['make'].value_counts())
cars
# Out:
#        mileage        make   model               fuel    gear       offerType  \
# 0       235000         BMW     316             Diesel  Manual            Used
# 1        92800  Volkswagen    Golf           Gasoline  Manual            Used
# 2       149300        SEAT    Exeo           Gasoline  Manual            Used
# 3        96200     Renault  Megane           Gasoline  Manual            Used
# 4       156000     Peugeot     308           Gasoline  Manual            Used
# ...        ...         ...     ...                ...     ...             ...
# 46257       99        Fiat     500  Electric/Gasoline  Manual  Pre-registered
# 46258       99        Fiat     500  Electric/Gasoline  Manual  Pre-registered
# 46259       99        Fiat     500  Electric/Gasoline  Manual  Pre-registered
# 46260       99        Fiat     500  Electric/Gasoline  Manual  Pre-registered
# 46261       99        Fiat     500  Electric/Gasoline  Manual  Pre-registered
#
#        price     hp  year      hp-bin     price-bin fuel_group new/used  \
# 0       6800 116.00  2011  100-200 hp      < 10000€     Diesel     Used
# 1       6877 122.00  2011  100-200 hp      < 10000€   Gasoline     Used
# 2       6900 160.00  2011  100-200 hp      < 10000€   Gasoline     Used
# 3       6950 110.00  2011  100-200 hp      < 10000€   Gasoline     Used
# 4       6950 156.00  2011  100-200 hp      < 10000€   Gasoline     Used
# ...      ...    ...   ...         ...           ...        ...      ...
# 46257  12990  71.00  2021    5-100 hp  10000-20000€     Hybrid      New
# 46258  12990  71.00  2021    5-100 hp  10000-20000€     Hybrid      New
# 46259  12990  71.00  2021    5-100 hp  10000-20000€     Hybrid      New
# 46260  12990  71.00  2021    5-100 hp  10000-20000€     Hybrid      New
# 46261  12990  71.00  2021    5-100 hp  10000-20000€     Hybrid      New
#
#        model_available  make_count
# 0                   49        2400
# 1                 1492        6921
# 2                   15        1924
# 3                  389        2828
# 4                  179        1232
# ...                ...         ...
# 46257              666        1700
# 46258              666        1700
# 46259              666        1700
# 46260              666        1700
# 46261              666        1700
#
# [46262 rows x 15 columns]

# %%
# Find out top 10 of models, which are most represented

model_avg = cars[['make', 'model','price', 'model_available', 'mileage']]
model_avg = model_avg.groupby(['make', 'model'], as_index = False).mean()
model_avg = model_avg.sort_values(by = 'model_available', ascending = False)
top10_models = model_avg.head(10)
top10_models.reset_index(drop = True, inplace = True)
top10_models
# Out:
#          make   model    price  model_available   mileage
# 0  Volkswagen    Golf 13540.55          1492.00  91738.14
# 1        Opel   Corsa  8959.63          1491.00  55012.01
# 2        Ford  Fiesta  9864.22          1289.00  52437.59
# 3        Opel   Astra  9574.46          1191.00 101118.97
# 4        Ford   Focus 12428.89           985.00  83752.35
# 5  Volkswagen     up!  7622.25           945.00  55040.93
# 6       Skoda   Fabia 10170.06           917.00  55746.15
# 7  Volkswagen    Polo 10053.58           893.00  68183.68
# 8       smart  forTwo  7878.90           725.00  55304.53
# 9        Fiat     500 11022.25           666.00  25588.98

# %% [markdown]
# And now we are going to check models, that are represented just once on AutoScaut24

# %%
rare_models = cars.loc[cars['model_available'] == 1]
rare_models[['make', 'model', 'price', 'hp', 'mileage']]
# Out:
#                 make          model   price     hp  mileage
# 762    Mercedes-Benz        GLS 500   86885 455.00     2267
# 3401        Chrysler  Grand Voyager    9999 287.00   145000
# 3630      Volkswagen     Cross Golf    9900 160.00    87000
# 4567   Mercedes-Benz        SLC 200   36950 184.00    44000
# 5080           Dodge          Nitro    9700 260.00   107130
# ...              ...            ...     ...    ...      ...
# 45603  Mercedes-Benz          S 260  134999 330.00       15
# 45985            Kia         e-Niro   37480 204.00       35
# 46102         Alpine           A110   74990 292.00     3112
# 46183            BMW            iX3   58000 286.00       45
# 46219         Nissan          NV250   16990 116.00      100
#
# [133 rows x 5 columns]

# %%
# Select only numeric columns for aggregation
make_avg = cars[['make', 'price', 'make_count', 'mileage']]

# Group by 'make' and calculate the mean of numeric columns
make_avg = make_avg.groupby(['make'], as_index=False).mean()

# Sort by 'make_count' to get the most represented makes
make_avg = make_avg.sort_values(by='make_count', ascending=False)

# Get the top 10 makes
top10_make = make_avg.head(10)

# Reset the index of the DataFrame
top10_make.reset_index(drop=True, inplace=True)

# Display the top 10 makes with average stats
top10_make
# Out:
#             make    price  make_count  mileage
# 0     Volkswagen 16060.09     6921.00 80881.04
# 1           Opel 10428.03     4801.00 78416.94
# 2           Ford 13793.37     4441.00 69201.89
# 3          Skoda 13715.19     2877.00 70644.23
# 4        Renault 11287.90     2828.00 57111.05
# 5           Audi 30000.23     2681.00 76796.27
# 6            BMW 23431.07     2400.00 97489.55
# 7  Mercedes-Benz 28379.92     2347.00 96164.90
# 8           SEAT 12847.43     1924.00 66158.88
# 9        Hyundai 12852.69     1886.00 52792.60

# %%
# Find out rare make of cars

rare10_make = cars.loc[cars['make_count'] == 1]
rare10_make.reset_index(drop = True, inplace = True)
rare10_make[['make', 'model', 'price', 'hp', 'mileage', 'make_count']]
# Out:
#              make            model  price     hp  mileage  make_count
# 0          Zhidou              D2S  12500  24.00     3000           1
# 1         Tazzari  EV Zero Classic   6500  20.00    38000           1
# 2      Trucks-Lkw             Ford   8200 131.00   312000           1
# 3      Brilliance              BS4   1500 101.00   100524           1
# 4          FISKER            Karma  69900 408.00     7500           1
# 5          Others         Landwind   1850  97.00        1           1
# 6           Isuzu            D-Max  16900 163.00    56000           1
# 7  Caravans-Wohnm            Adria  24500 132.99     2000           1
# 8          Alpine             A110  74990 292.00     3112           1

# %%
# Top 10 most expensive cars represented on AutoScout24

cars_sorted = cars.sort_values(by = 'price', ascending = False)
top10_expensive = cars_sorted.head(10)
top10_expensive.reset_index(drop = True, inplace = True)
top10_expensive[['make', 'model', 'price', 'hp', 'mileage']]
# Out:
#             make      model    price     hp  mileage
# 0        Ferrari        F12  1199900 775.00      431
# 1  Mercedes-Benz      S 650   717078 630.00       90
# 2        Maybach    Pullman   717078 630.00       90
# 3        Maybach    Pullman   499800 530.00     3400
# 4  Mercedes-Benz        SLS   465000 591.00      350
# 5    Lamborghini  Aventador   449900 770.00     3600
# 6        Ferrari        812   439900 799.00     6500
# 7    Lamborghini  Aventador   439900 770.00    14090
# 8    Lamborghini  Aventador   399999 700.00     1200
# 9        Porsche        991   399911 700.00     4624

# %%
# Top 10 cheapest cars represented on AutoScout24

top10_cheapest = cars_sorted.tail(10)
top10_cheapest = top10_cheapest.sort_values(by = 'price', ascending = True)
top10_cheapest.reset_index(drop = True, inplace = True)
top10_cheapest[['make', 'model', 'price', 'hp', 'mileage']]
# Out:
#          make   model  price     hp  mileage
# 0     Citroen      C1   1100  68.00   204000
# 1        Lada  Priora   1190  98.00   100611
# 2      Toyota    Aygo   1250  68.00   153000
# 3     Peugeot     206   1299  68.00   222000
# 4        Opel   Corsa   1300  69.00   133000
# 5  Volkswagen  Touran   1396 140.00   233567
# 6  Brilliance     BS4   1500 101.00   100524
# 7        SEAT   Ibiza   1500  69.00   170000
# 8       smart  forTwo   1500  54.00   140000
# 9        Fiat   Panda   1500  69.00   157000

# %%
cars_sorted_hp = cars.sort_values(by = 'hp', ascending = False)
top10hp = cars_sorted_hp.head(10)
top10hp = top10hp.reset_index()
top10hp[['make', 'model', 'price', 'hp', 'mileage']]
# Out:
#             make      model    price     hp  mileage
# 0  Mercedes-Benz   G 63 AMG   216619 850.00     9234
# 1           Audi         R8   295000 799.00    11000
# 2        Ferrari        812   439900 799.00     6500
# 3        Ferrari        F12  1199900 775.00      431
# 4          Tesla    Model S    54450 772.00    71099
# 5          Tesla    Model X    99999 772.00    63205
# 6           Ford    Mustang   121000 771.00       50
# 7    Lamborghini  Aventador   439900 770.00    14090
# 8    Lamborghini  Aventador   449900 770.00     3600
# 9       Corvette        Z06   148600 767.00     9790

# %%
c = cars.loc[cars['hp'] <= 20]
c['model'].unique()
# Out:
# array(['Due', 'Twizy', 'JS 50', 'City', 'Ape', 'M.Go', 'EV Zero Classic',
#        'M8', 'Kona', 'Birò'], dtype=object)

# %%
hp_avg = cars[['make', 'model','price', 'hp', 'model_available', 'mileage']]
hp_avg = hp_avg.groupby(['make', 'model'], as_index = False).mean()
hp_avg = hp_avg.sort_values(by = 'hp', ascending = True)
bot10_hp = hp_avg.head(10)
bot10_hp.reset_index(drop = True, inplace = True)
bot10_hp
# Out:
#        make            model    price    hp  model_available  mileage
# 0    Ligier            JS 50  9570.00  5.00             5.00 30447.40
# 1   Estrima             Birò 13090.00  5.00             2.00   225.00
# 2  Microcar             M.Go  8262.86  5.86             7.00 30994.71
# 3  Microcar               M8  6149.50  6.00             7.00 32283.00
# 4     Aixam             City 12935.00  6.50             2.00   602.50
# 5  Microcar              Due  6745.00  7.50             2.00 37650.00
# 6   Piaggio              Ape  7849.75 10.25             4.00 16125.00
# 7   Renault            Twizy  5413.43 10.74            23.00 23813.43
# 8   Tazzari  EV Zero Classic  6500.00 20.00             1.00 38000.00
# 9    Zhidou              D2S 12500.00 24.00             1.00  3000.00
